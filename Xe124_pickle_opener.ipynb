# %%
import pickle

# %%
# Replace 'your_file.pkl' with the path to your pickle file
filepath = '/global/cfs/cdirs/lz/users/rory_m/XLZD/FlameFitSimple/analyses/wimp_sensitivity/outputs/SI_60t_benchmark/'
filename = 'p_value_dists.pkl'
#filename = '136Xe_spectrum.pkl'
with open(filepath+filename, 'rb') as file:
    data = pickle.load(file)

# Now `data` contains the unpickled object
print(data)
# Out:
# 2025-05-27 09:01:32.461898: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748361692.483883 2260875 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748361692.490760 2260875 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1748361692.511243 2260875 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# Replace 'your_file.pkl' with the path to your pickle file
filepath = '/global/homes/r/rory_m/.conda/envs/flamedisx_2.0/lib/python3.11/site-packages/flamedisx/nest/background_spectra/'
filename = '124Xe_spectrum.pkl'
#filename = '136Xe_spectrum.pkl'
with open(filepath+filename, 'rb') as file:
    data = pickle.load(file)

# Now `data` contains the unpickled object
print(data)

# %%
import numpy
print(numpy.__version__)
# Out:
# 2.2.5

# %%
import pickletools

with open(filepath+filename, 'rb') as f:
    pickletools.dis(f)
# Out:
#     0: \x80 PROTO      5
#     2: \x95 FRAME      803
#    11: \x8c SHORT_BINUNICODE 'pandas.core.frame'
#    30: \x94 MEMOIZE    (as 0)
#    31: \x8c SHORT_BINUNICODE 'DataFrame'
#    42: \x94 MEMOIZE    (as 1)
#    43: \x93 STACK_GLOBAL
#    44: \x94 MEMOIZE    (as 2)
#    45: )    EMPTY_TUPLE
#    46: \x81 NEWOBJ
#    47: \x94 MEMOIZE    (as 3)
#    48: }    EMPTY_DICT
#    49: \x94 MEMOIZE    (as 4)
#    50: (    MARK
#    51: \x8c     SHORT_BINUNICODE '_mgr'
#    57: \x94     MEMOIZE    (as 5)
#    58: \x8c     SHORT_BINUNICODE 'pandas.core.internals.managers'
#    90: \x94     MEMOIZE    (as 6)
#    91: \x8c     SHORT_BINUNICODE 'BlockManager'
#   105: \x94     MEMOIZE    (as 7)
#   106: \x93     STACK_GLOBAL
#   107: \x94     MEMOIZE    (as 8)
#   108: \x8c     SHORT_BINUNICODE 'pandas._libs.internals'
#   132: \x94     MEMOIZE    (as 9)
#   133: \x8c     SHORT_BINUNICODE '_unpickle_block'
#   150: \x94     MEMOIZE    (as 10)
#   151: \x93     STACK_GLOBAL
# ...
