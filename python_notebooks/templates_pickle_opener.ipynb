# %%
import pickle
import matplotlib.pyplot as plt

# %%
# Replace 'your_file.pkl' with the path to your pickle file
filepath = '/global/homes/r/rory_m/rory_m/XLZD/FlameFitSimple/analyses/WIMP_discovery/background_templates/'
folder = '2D_neutrons/'
filename = '2D_neutrons_0.1'

with open(filepath+folder+filename+'.pkl', 'rb') as file:
    data = pickle.load(file)


print(data)
# Out:
# [{'SolarER': <multihist.Histdd object at 0x7ff74ed75d90>, 'Pb214': <multihist.Histdd object at 0x7ff754f24610>, 'Kr85': <multihist.Histdd object at 0x7ff74ed41010>, 'Xe136': <multihist.Histdd object at 0x7ff74ed43590>, 'Xe124': <multihist.Histdd object at 0x7ff74ed43710>, 'CEvNS_solar': <multihist.Histdd object at 0x7ff74ead2b50>, 'CEvNS_other_LNGS': <multihist.Histdd object at 0x7ff74e0dd910>, 'CEvNS_other_SURF': <multihist.Histdd object at 0x7ff74eda2c90>, 'neutrons_LNGS': <multihist.Histdd object at 0x7ff74e0b9690>}, {'WIMP10': <multihist.Histdd object at 0x7ff74e0d8790>, 'WIMP': <multihist.Histdd object at 0x7ff754fb2190>}]

# %%
hist = data[0]['neutrons_LNGS']
#print(dir(hist))

# %%
hist.plot()
plt.title(f"Template: {filename}  Counts:{hist.n :.5f}")
plt.show()
